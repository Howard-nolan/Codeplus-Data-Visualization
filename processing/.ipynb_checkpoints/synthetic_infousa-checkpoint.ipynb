# %%
import pandas as pd
import random
import os

# %%
DATA_DIR = os.getcwd()
DATA_DIR = DATA_DIR.replace('processing', 'data')
DATA_DIR
# Out:
# '/hpc/home/at341/ondemand/codeplus-celine-dcc-package/data'

# %%
# %%time
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
age_codes = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']

random.seed(1)

for i in range(10):  
    zipcode = random.randint(10000, 99999)
    print(zipcode)
    ZIP = []
    census_county_2010 = []
    census_state_2010 = []
    ChildrenHHCount = []
    length_of_residence = []
    children_ind = []
    GE_LONGITUDE_2010 = []
    GE_LATITUDE_2010 = []
    STATE = []
    head_hh_age_code = []
    
    for i in range (0, 100000):
        ZIP.append(random.randint(10000, 99999))
        census_county_2010.append(str(random.randint(0, 5)) + str(random.randint(0, 9)) + str(random.randint(0, 9)))
        census_state_2010.append(str(random.randint(0, 5)) + str(random.randint(0, 9)))                                          
        STATE.append(states[random.randint(0, 50)])
        ChildrenHHCount.append(random.randint(0, 15))
        length_of_residence.append(random.randint(0, 70))
        children_ind.append(random.randint(0,1))
        head_hh_age_code.append(age_codes[random.randint(0, 12)])
        GE_LONGITUDE_2010.append(random.uniform(-125, -65))
        GE_LATITUDE_2010.append(random.uniform(35, 50))

    # print(len(ZIP))
    # print(len(census_county_2010))
    # print(len(ChildrenHHCount))
    # print(len(length_of_residence))
    # print(len(children_ind))
    # print(len(GE_LONGITUDE_2010))
    # print(len(GE_LATITUDE_2010))
    # print(len(STATE))
    # print(len(head_hh_age_code))
   
    d = {'ZIP': ZIP, 'census_county_2010': census_county_2010, 'census_state_2010': census_state_2010, 'STATE': STATE, 
         'ChildrenHHCount': ChildrenHHCount, 'length_of_residence': length_of_residence, 
         'children_ind': children_ind, 'head_hh_age_code': head_hh_age_code, 'GE_LATITUDE_2010': GE_LATITUDE_2010, 
         'GE_LONGITUDE_2010': GE_LONGITUDE_2010}
    df_synthetic = pd.DataFrame(d)
    df_synthetic
    df_synthetic.to_csv(DATA_DIR + '/source_files/infousa_files/Household_Ethnicity_zip_' + str(zipcode) + '_year_2020.txt', sep = '\t', index = False)
# Out:
# 27611
# 26238
# 43975
# 44452
# 46782
# 63537
# 87821
# 37619
# 48736
# 17556
# CPU times: user 14 s, sys: 132 ms, total: 14.1 s
# Wall time: 14.5 s

# %%
f = pd.read_csv(DATA_DIR + '/source_files/infousa_files/Household_Ethnicity_zip_27611_year_2020.txt', sep = '\t')
f
# Out:
#          ZIP  census_county_2010  census_state_2010 STATE  ChildrenHHCount  \
# 0      84606                  41                 37    NH               12
# 1      66723                 407                 23    OR                3
# 2      59965                 536                 50    NV                7
# 3      38676                 340                 38    SD                3
# 4      75640                 383                 24    OR               15
# ...      ...                 ...                ...   ...              ...
# 99995  55400                 178                  7    MO               12
# 99996  61004                  28                 11    KY                8
# 99997  41297                 120                 33    ME               13
# 99998  85493                 431                 34    NE                3
# 99999  72711                 261                 46    KS                0
#
#        length_of_residence  children_ind head_hh_age_code  GE_LATITUDE_2010  \
# 0                       26             0                H         47.536477
# 1                       40             0                A         43.121187
# 2                       56             1                I         38.462998
# 3                       23             1                B         48.433631
# 4                       64             1                J         42.203405
# ...                    ...           ...              ...               ...
# 99995                    9             1                H         44.864827
# 99996                   70             0                I         40.400824
# 99997                    2             1                E         42.272343
# 99998                   32             1                M         41.104769
# 99999                   19             0                D         36.767946
#
#        GE_LONGITUDE_2010
# 0            -123.299151
# 1            -123.473248
# 2            -111.014933
# 3             -80.411200
# 4             -73.802723
# ...                  ...
# 99995         -79.603654
# 99996         -70.549045
# 99997        -100.471747
# 99998         -81.442617
# 99999         -84.537195
#
# [100000 rows x 10 columns]

# %% [markdown]
# ### Synthetic Case Study Data

# %% [markdown]
# #### Charleston County

# %%
# %%time

age_codes = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']

random.seed(1)

ZIP = []
census_county_2010 = []
census_state_2010 = []
ChildrenHHCount = []
length_of_residence = []
children_ind = []
GE_LONGITUDE_2010 = []
GE_LATITUDE_2010 = []
STATE = []
head_hh_age_code = []
    
for i in range (0, 100000):
    ZIP.append(random.randint(29400, 29500))
    census_county_2010.append('019')
    census_state_2010.append('45')                                          
    STATE.append('SC')
    ChildrenHHCount.append(random.randint(0, 15))
    length_of_residence.append(random.randint(0, 70))
    children_ind.append(random.randint(0,1))
    head_hh_age_code.append(age_codes[random.randint(0, 12)])
    GE_LONGITUDE_2010.append(random.uniform(-80.370, -79.460))
    GE_LATITUDE_2010.append(random.uniform(32.650, 33.080))
# print(len(ZIP))
# print(len(census_county_2010))
# print(len(ChildrenHHCount))
# print(len(length_of_residence))
# print(len(children_ind))
# print(len(GE_LONGITUDE_2010))
# print(len(GE_LATITUDE_2010))
# print(len(STATE))
# print(len(head_hh_age_code))
   
d = {'ZIP': ZIP, 'census_county_2010': census_county_2010, 'census_state_2010': census_state_2010, 'STATE': STATE, 
     'ChildrenHHCount': ChildrenHHCount, 'length_of_residence': length_of_residence, 
     'children_ind': children_ind, 'head_hh_age_code': head_hh_age_code, 'GE_LATITUDE_2010': GE_LATITUDE_2010, 
     'GE_LONGITUDE_2010': GE_LONGITUDE_2010}
df_synthetic_charleston = pd.DataFrame(d)
df_synthetic_charleston
# Out:
# CPU times: user 577 ms, sys: 16.9 ms, total: 593 ms
# Wall time: 594 ms
#          ZIP census_county_2010 census_state_2010 STATE  ChildrenHHCount  \
# 0      29417                019                45    SC                2
# 1      29448                019                45    SC                6
# 2      29477                019                45    SC                0
# 3      29413                019                45    SC               10
# 4      29448                019                45    SC                6
# ...      ...                ...               ...   ...              ...
# 99995  29451                019                45    SC                4
# 99996  29415                019                45    SC                0
# 99997  29472                019                45    SC                9
# 99998  29431                019                45    SC                2
# 99999  29462                019                45    SC               11
#
#        length_of_residence  children_ind head_hh_age_code  GE_LATITUDE_2010  \
# 0                       32             0                H         32.853065
# 1                       12             1                A         32.817618
# 2                       57             1                L         32.904196
# 3                        3             0                A         32.653958
# 4                       54             0                I         32.838292
# ...                    ...           ...              ...               ...
# 99995                   34             1                G         32.859898
# 99996                   37             1                I         32.976982
# 99997                   23             1                C         33.027838
# 99998                   18             0                M         32.805037
# 99999                   60             0                J         32.935773
#
#        GE_LONGITUDE_2010
# 0             -79.677524
# 1             -79.557081
# 2             -79.640338
# 3             -79.778913
# 4             -80.168261
# ...                  ...
# 99995         -79.983927
# 99996         -80.108903
# 99997         -79.829499
# 99998         -79.584401
# 99999         -80.144378
#
# [100000 rows x 10 columns]

# %% [markdown]
# ##### Processing

# %%
# %%time
df_synthetic_charleston['county_fips'] = df_synthetic_charleston['census_state_2010'] + df_synthetic_charleston['census_county_2010']

df_synthetic_charleston = df_synthetic_charleston[['ZIP', 'county_fips', 'STATE', 'ChildrenHHCount', 'children_ind', 'head_hh_age_code', 
                                           'GE_LATITUDE_2010', 'GE_LONGITUDE_2010']]
df_synthetic_charleston
# Out:
# CPU times: user 15.4 ms, sys: 1.05 ms, total: 16.4 ms
# Wall time: 14.9 ms
#          ZIP county_fips STATE  ChildrenHHCount  children_ind  \
# 0      29417       45019    SC                2             0
# 1      29448       45019    SC                6             1
# 2      29477       45019    SC                0             1
# 3      29413       45019    SC               10             0
# 4      29448       45019    SC                6             0
# ...      ...         ...   ...              ...           ...
# 99995  29451       45019    SC                4             1
# 99996  29415       45019    SC                0             1
# 99997  29472       45019    SC                9             1
# 99998  29431       45019    SC                2             0
# 99999  29462       45019    SC               11             0
#
#       head_hh_age_code  GE_LATITUDE_2010  GE_LONGITUDE_2010
# 0                    H         32.853065         -79.677524
# 1                    A         32.817618         -79.557081
# 2                    L         32.904196         -79.640338
# 3                    A         32.653958         -79.778913
# 4                    I         32.838292         -80.168261
# ...                ...               ...                ...
# 99995                G         32.859898         -79.983927
# 99996                I         32.976982         -80.108903
# 99997                C         33.027838         -79.829499
# 99998                M         32.805037         -79.584401
# 99999                J         32.935773         -80.144378
#
# [100000 rows x 8 columns]

# %% [markdown]
# **Renaming columns**:
# We rename the columns in our dataset for standardization purposes.

# %%
df_synthetic_charleston.rename(columns = {'ZIP': 'zip', 'STATE': 'state', 'ChildrenHHCount': 'child_num', 
                           'children_ind': 'has_child', 'head_hh_age_code': 'age_code', 'GE_LATITUDE_2010': 'lat_h_4326', 
                            'GE_LONGITUDE_2010': 'lon_h_4326'}, inplace = True)
df_synthetic_charleston
# Out:
# /tmp/ipykernel_2253387/3496990244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synthetic_charleston.rename(columns = {'ZIP': 'zip', 'STATE': 'state', 'ChildrenHHCount': 'child_num',
#          zip county_fips state  child_num  has_child age_code  lat_h_4326  \
# 0      29417       45019    SC          2          0        H   32.853065
# 1      29448       45019    SC          6          1        A   32.817618
# 2      29477       45019    SC          0          1        L   32.904196
# 3      29413       45019    SC         10          0        A   32.653958
# 4      29448       45019    SC          6          0        I   32.838292
# ...      ...         ...   ...        ...        ...      ...         ...
# 99995  29451       45019    SC          4          1        G   32.859898
# 99996  29415       45019    SC          0          1        I   32.976982
# 99997  29472       45019    SC          9          1        C   33.027838
# 99998  29431       45019    SC          2          0        M   32.805037
# 99999  29462       45019    SC         11          0        J   32.935773
#
#        lon_h_4326
# 0      -79.677524
# 1      -79.557081
# 2      -79.640338
# 3      -79.778913
# 4      -80.168261
# ...           ...
# 99995  -79.983927
# 99996  -80.108903
# 99997  -79.829499
# 99998  -79.584401
# 99999  -80.144378
#
# [100000 rows x 8 columns]

# %% [markdown]
# **Transforming household latitude and longitude coordinates from EPSG 4326 to EPSG 3857**.
# A lot of our visualizations need coordinates in EPSG 3857, however these coordinates are in EPSG 4326. Therefore, we use the pyproj interface, which allows us to use the PROJ coordinate transformation software to transform our EPSG 4326 coordinates to EPSG 3857. This creates two new columns in our original dataset with the transformed coordinates.

# %%
from pyproj import Proj, Transformer

# %%
# Apply transformation
transform_4326_to_3857 = Transformer.from_crs('epsg:4326', 'epsg:3857')
df_synthetic_charleston['lat_h_3857'], df_synthetic_charleston['lon_h_3857'] = transform_4326_to_3857.transform(
                                                df_synthetic_charleston['lat_h_4326'], df_synthetic_charleston['lon_h_4326'])

df_synthetic_charleston
# Out:
# /tmp/ipykernel_2253387/584665642.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synthetic_charleston['lat_h_3857'], df_synthetic_charleston['lon_h_3857'] = transform_4326_to_3857.transform(
# /tmp/ipykernel_2253387/584665642.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synthetic_charleston['lat_h_3857'], df_synthetic_charleston['lon_h_3857'] = transform_4326_to_3857.transform(
#          zip county_fips state  child_num  has_child age_code  lat_h_4326  \
# 0      29417       45019    SC          2          0        H   32.853065
# 1      29448       45019    SC          6          1        A   32.817618
# 2      29477       45019    SC          0          1        L   32.904196
# 3      29413       45019    SC         10          0        A   32.653958
# 4      29448       45019    SC          6          0        I   32.838292
# ...      ...         ...   ...        ...        ...      ...         ...
# 99995  29451       45019    SC          4          1        G   32.859898
# 99996  29415       45019    SC          0          1        I   32.976982
# 99997  29472       45019    SC          9          1        C   33.027838
# 99998  29431       45019    SC          2          0        M   32.805037
# 99999  29462       45019    SC         11          0        J   32.935773
#
#        lon_h_4326    lat_h_3857    lon_h_3857
# 0      -79.677524 -8.869661e+06  3.875817e+06
# 1      -79.557081 -8.856254e+06  3.871121e+06
# 2      -79.640338 -8.865522e+06  3.882594e+06
# 3      -79.778913 -8.880948e+06  3.849462e+06
# 4      -80.168261 -8.924290e+06  3.873860e+06
# ...           ...           ...           ...
# 99995  -79.983927 -8.903770e+06  3.876722e+06
# 99996  -80.108903 -8.917682e+06  3.892249e+06
# 99997  -79.829499 -8.886579e+06  3.899000e+06
# 99998  -79.584401 -8.859295e+06  3.869454e+06
# 99999  -80.144378 -8.921631e+06  3.886782e+06
#
# [100000 rows x 10 columns]

# %% [markdown]
# **Exporting final dataframe**. Finally, we export this dataframe as a ```.parquet()``` file for further use.

# %%
# %%time
df_synthetic_charleston.to_parquet(DATA_DIR + '/source_files/infousa_files/charleston_households.parquet')
# Out:
# CPU times: user 73 ms, sys: 17.7 ms, total: 90.7 ms
# Wall time: 112 ms

# %% [markdown]
# #### Harris County

# %%
# %%time

age_codes = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']

random.seed(1)

ZIP = []
census_county_2010 = []
census_state_2010 = []
ChildrenHHCount = []
length_of_residence = []
children_ind = []
GE_LONGITUDE_2010 = []
GE_LATITUDE_2010 = []
STATE = []
head_hh_age_code = []
    
for i in range (0, 500000):
    ZIP.append(random.randint(77000, 77300))
    census_county_2010.append('201')
    census_state_2010.append('48')                                          
    STATE.append('TX')
    ChildrenHHCount.append(random.randint(0, 15))
    length_of_residence.append(random.randint(0, 70))
    children_ind.append(random.randint(0,1))
    head_hh_age_code.append(age_codes[random.randint(0, 12)])
    GE_LONGITUDE_2010.append(random.uniform(-95.820, -94.960))
    GE_LATITUDE_2010.append(random.uniform(29.530, 30.120))
    
# print(len(ZIP))
# print(len(census_county_2010))
# print(len(ChildrenHHCount))
# print(len(length_of_residence))
# print(len(children_ind))
# print(len(GE_LONGITUDE_2010))
# print(len(GE_LATITUDE_2010))
# print(len(STATE))
# print(len(head_hh_age_code))
   
d = {'ZIP': ZIP, 'census_county_2010': census_county_2010, 'census_state_2010': census_state_2010, 'STATE': STATE, 
     'ChildrenHHCount': ChildrenHHCount, 'length_of_residence': length_of_residence, 
     'children_ind': children_ind, 'head_hh_age_code': head_hh_age_code, 'GE_LATITUDE_2010': GE_LATITUDE_2010, 
     'GE_LONGITUDE_2010': GE_LONGITUDE_2010}
df_synthetic_harris = pd.DataFrame(d)
df_synthetic_harris
# Out:
# CPU times: user 2.66 s, sys: 54.5 ms, total: 2.71 s
# Wall time: 2.72 s
#           ZIP census_county_2010 census_state_2010 STATE  ChildrenHHCount  \
# 0       77068                201                48    TX                2
# 1       77194                201                48    TX                6
# 2       77001                201                48    TX               14
# 3       77015                201                48    TX                0
# 4       77014                201                48    TX                7
# ...       ...                ...               ...   ...              ...
# 499995  77191                201                48    TX                5
# 499996  77050                201                48    TX               10
# 499997  77242                201                48    TX                8
# 499998  77238                201                48    TX               10
# 499999  77175                201                48    TX               10
#
#         length_of_residence  children_ind head_hh_age_code  GE_LATITUDE_2010  \
# 0                        32             0                H         29.808625
# 1                        12             1                A         29.759987
# 2                        34             0                J         30.061842
# 3                         3             0                G         30.101734
# 4                        56             1                I         29.666211
# ...                     ...           ...              ...               ...
# 499995                   31             1                E         29.905114
# 499996                   60             1                M         30.028496
# 499997                   46             1                A         29.913911
# 499998                   23             1                F         30.069060
# 499999                    3             0                J         29.951907
#
#         GE_LONGITUDE_2010
# 0              -95.165572
# 1              -95.051747
# 2              -95.007067
# 3              -95.229624
# 4              -95.619547
# ...                   ...
# 499995         -95.675370
# 499996         -95.755345
# 499997         -95.466206
# 499998         -95.759268
# 499999         -95.403127
#
# [500000 rows x 10 columns]

# %% [markdown]
# ##### Processing

# %%
# %%time
df_synthetic_harris['county_fips'] = df_synthetic_harris['census_state_2010'] + df_synthetic_harris['census_county_2010']

df_synthetic_harris = df_synthetic_harris[['ZIP', 'county_fips', 'STATE', 'ChildrenHHCount', 'children_ind', 'head_hh_age_code', 
                                           'GE_LATITUDE_2010', 'GE_LONGITUDE_2010']]
df_synthetic_harris
# Out:
# CPU times: user 95.3 ms, sys: 13.8 ms, total: 109 ms
# Wall time: 107 ms
#           ZIP county_fips STATE  ChildrenHHCount  children_ind  \
# 0       77068       48201    TX                2             0
# 1       77194       48201    TX                6             1
# 2       77001       48201    TX               14             0
# 3       77015       48201    TX                0             0
# 4       77014       48201    TX                7             1
# ...       ...         ...   ...              ...           ...
# 499995  77191       48201    TX                5             1
# 499996  77050       48201    TX               10             1
# 499997  77242       48201    TX                8             1
# 499998  77238       48201    TX               10             1
# 499999  77175       48201    TX               10             0
#
#        head_hh_age_code  GE_LATITUDE_2010  GE_LONGITUDE_2010
# 0                     H         29.808625         -95.165572
# 1                     A         29.759987         -95.051747
# 2                     J         30.061842         -95.007067
# 3                     G         30.101734         -95.229624
# 4                     I         29.666211         -95.619547
# ...                 ...               ...                ...
# 499995                E         29.905114         -95.675370
# 499996                M         30.028496         -95.755345
# 499997                A         29.913911         -95.466206
# 499998                F         30.069060         -95.759268
# 499999                J         29.951907         -95.403127
#
# [500000 rows x 8 columns]

# %% [markdown]
# **Renaming columns**:
# We rename the columns in our dataset for standardization purposes.

# %%
df_synthetic_harris.rename(columns = {'ZIP': 'zip', 'STATE': 'state', 'ChildrenHHCount': 'child_num', 
                           'children_ind': 'has_child', 'head_hh_age_code': 'age_code', 'GE_LATITUDE_2010': 'lat_h_4326', 
                            'GE_LONGITUDE_2010': 'lon_h_4326'}, inplace = True)
df_synthetic_harris
# Out:
# /tmp/ipykernel_2253387/18126817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synthetic_harris.rename(columns = {'ZIP': 'zip', 'STATE': 'state', 'ChildrenHHCount': 'child_num',
#           zip county_fips state  child_num  has_child age_code  lat_h_4326  \
# 0       77068       48201    TX          2          0        H   29.808625
# 1       77194       48201    TX          6          1        A   29.759987
# 2       77001       48201    TX         14          0        J   30.061842
# 3       77015       48201    TX          0          0        G   30.101734
# 4       77014       48201    TX          7          1        I   29.666211
# ...       ...         ...   ...        ...        ...      ...         ...
# 499995  77191       48201    TX          5          1        E   29.905114
# 499996  77050       48201    TX         10          1        M   30.028496
# 499997  77242       48201    TX          8          1        A   29.913911
# 499998  77238       48201    TX         10          1        F   30.069060
# 499999  77175       48201    TX         10          0        J   29.951907
#
#         lon_h_4326
# 0       -95.165572
# 1       -95.051747
# 2       -95.007067
# 3       -95.229624
# 4       -95.619547
# ...            ...
# 499995  -95.675370
# 499996  -95.755345
# 499997  -95.466206
# 499998  -95.759268
# 499999  -95.403127
#
# [500000 rows x 8 columns]

# %% [markdown]
# **Transforming household latitude and longitude coordinates from EPSG 4326 to EPSG 3857**.
# A lot of our visualizations need coordinates in EPSG 3857, however these coordinates are in EPSG 4326. Therefore, we use the pyproj interface, which allows us to use the PROJ coordinate transformation software to transform our EPSG 4326 coordinates to EPSG 3857. This creates two new columns in our original dataset with the transformed coordinates.

# %%
from pyproj import Proj, Transformer

# %%
# Apply transformation
transform_4326_to_3857 = Transformer.from_crs('epsg:4326', 'epsg:3857')
df_synthetic_harris['lat_h_3857'], df_synthetic_harris['lon_h_3857'] = transform_4326_to_3857.transform(
                                                df_synthetic_harris['lat_h_4326'], df_synthetic_harris['lon_h_4326'])

df_synthetic_harris
# Out:
# /tmp/ipykernel_2253387/2311750489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synthetic_harris['lat_h_3857'], df_synthetic_harris['lon_h_3857'] = transform_4326_to_3857.transform(
# /tmp/ipykernel_2253387/2311750489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synthetic_harris['lat_h_3857'], df_synthetic_harris['lon_h_3857'] = transform_4326_to_3857.transform(
#           zip county_fips state  child_num  has_child age_code  lat_h_4326  \
# 0       77068       48201    TX          2          0        H   29.808625
# 1       77194       48201    TX          6          1        A   29.759987
# 2       77001       48201    TX         14          0        J   30.061842
# 3       77015       48201    TX          0          0        G   30.101734
# 4       77014       48201    TX          7          1        I   29.666211
# ...       ...         ...   ...        ...        ...      ...         ...
# 499995  77191       48201    TX          5          1        E   29.905114
# 499996  77050       48201    TX         10          1        M   30.028496
# 499997  77242       48201    TX          8          1        A   29.913911
# 499998  77238       48201    TX         10          1        F   30.069060
# 499999  77175       48201    TX         10          0        J   29.951907
#
#         lon_h_4326    lat_h_3857    lon_h_3857
# 0       -95.165572 -1.059378e+07  3.478974e+06
# 1       -95.051747 -1.058111e+07  3.472736e+06
# 2       -95.007067 -1.057614e+07  3.511502e+06
# 3       -95.229624 -1.060091e+07  3.516634e+06
# 4       -95.619547 -1.064432e+07  3.460716e+06
# ...            ...           ...           ...
# 499995  -95.675370 -1.065053e+07  3.491359e+06
# 499996  -95.755345 -1.065944e+07  3.507213e+06
# 499997  -95.466206 -1.062725e+07  3.492489e+06
# 499998  -95.759268 -1.065987e+07  3.512430e+06
# 499999  -95.403127 -1.062023e+07  3.497369e+06
#
# [500000 rows x 10 columns]

# %% [markdown]
# **Exporting final dataframe**. Finally, we export this dataframe as a ```.parquet()``` file for further use.

# %%
# %%time
df_synthetic_harris.to_parquet(DATA_DIR + '/source_files/infousa_files/harris_households.parquet')
# Out:
# CPU times: user 306 ms, sys: 31.8 ms, total: 338 ms
# Wall time: 422 ms
