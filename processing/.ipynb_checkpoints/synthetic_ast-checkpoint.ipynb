# %%
import pandas as pd
import geopandas as gpd
import os
import random
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.11.0-CAPI-1.17.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
df_tanks = gpd.read_file('/hpc/group/codeplus22-vis/ast_dataset/tile_level_annotations.shp')
df_tanks
# Out:
#                           tile_name  minx_polyg  miny_polyg  maxx_polyg  \
# 0      m_4007327_nw_18_060_20190809         974         314        1041
# 1      m_4007327_nw_18_060_20190809        1091         479        1157
# 2      m_4007327_nw_18_060_20190809         851         243         872
# 3      m_4007327_nw_18_060_20190809         843         284         897
# 4      m_4007327_nw_18_060_20190809         905         288         945
# ...                             ...         ...         ...         ...
# 98164  m_3910409_se_13_060_20190803        2735        6826        2744
# 98165  m_3910409_se_13_060_20190803        2748        6851        2756
# 98166  m_3910409_se_13_060_20190803        2751        6778        2759
# 98167  m_3910409_se_13_060_20190803        2750        6975        2758
# 98168  m_3910409_se_13_060_20190803        2742        6975        2750
#
#        maxy_polyg  nw_corner_  nw_corne_1  se_corner_  se_corne_1  \
# ...

# %%
random.seed(1)
df_tanks_sample = df_tanks.sample(frac = 0.01)
df_tanks_sample = df_tanks_sample.reset_index(drop = True)
df_tanks_sample.to_file('/hpc/group/codeplus22-vis/synthetic_data/test/ast_synthetic2.shp')

# %%
df_tanks = gpd.read_file('/hpc/group/codeplus22-vis/synthetic_data/test/ast_synthetic2.shp')
df_tanks.head()
# Out:
#                       tile_name  minx_polyg  miny_polyg  maxx_polyg  \
# 0  m_3009057_ne_15_060_20190831        5886        3301        5960
# 1  m_3908801_nw_16_060_20191001        1359        7384        1378
# 2  m_3609659_sw_14_060_20190812         917       10119        1021
# 3  m_3808916_sw_16_060_20190713        6571        3413        6579
# 4  m_3308732_sw_16_060_20190908        2916         724        2948
#
#    maxy_polyg  nw_corner_  nw_corne_1  se_corner_  se_corne_1  \
# 0        3380   30.110301  -90.903770   30.109866  -90.903319
# 1        7404   39.962882  -88.994691   39.962777  -88.994555
# 2       10224   36.012151  -96.748673   36.011570  -96.747997
# 3        3423   38.797983  -89.084484   38.797930  -89.084427
# 4         756   33.560408  -87.108388   33.560235  -87.108181
#
#                     object_cla  diameter (  merged_bbo  bbox_withi  Category1  \
# 0             closed_roof_tank        44.4           0           0        0.0
# ...

# %% [markdown]
# ## Synthetic InfoUSA Data

# %%
directory = os.listdir("/hpc/group/codeplus22-vis/infousa_copy/2020")
directory
random.seed(0)
files = random.sample(directory, 10)
files
# Out:
# ['Household_Ethnicity_zip_49024_year_2020.txt',
#  'Household_Ethnicity_zip_55319_year_2020.txt',
#  'Household_Ethnicity_zip_96784_year_2020.txt',
#  'Household_Ethnicity_zip_49232_year_2020.txt',
#  'Household_Ethnicity_zip_90275_year_2020.txt',
#  'Household_Ethnicity_zip_24148_year_2020.txt',
#  'Household_Ethnicity_zip_73107_year_2020.txt',
#  'Household_Ethnicity_zip_48412_year_2020.txt',
#  'Household_Ethnicity_zip_14086_year_2020.txt',
#  'Household_Ethnicity_zip_77255_year_2020.txt']

# %% [markdown]
# #### Zip 49024

# %%
df_49024 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_49024_year_2020.txt', sep = '\t')
df_49024
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0           8510132             S                   1               F
# 1           9547193             S                   1               F
# 2          46939237             S                   0               F
# 3          47908447             S                   1               F
# 4          49345446             S                   1               F
# ...             ...           ...                 ...             ...
# 18255  902470975329             S                   1               F
# 18256  902470975387             S                   0               F
# 18257  902470975405             S                   1               F
# 18258  902470975413             S                   1               F
# 18259  902470975421             S                   0               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_49024 = df_49024.sample(frac=1)
df_49024
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 18094    1101621243             S                   1               F
# 16276  601763359215             S                   0               F
# 303    601537416445             S                   0               F
# 12827     300927794             S                   0               F
# 5800   401378841033             S                   0               F
# ...             ...           ...                 ...             ...
# 4581     1441677189             S                   1               F
# 7332   100300936735             S                   1               F
# 3020   902386068437             S                   1               F
# 2063   700300882709             S                   1               F
# 9939   800920830251             M                   1               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_49024.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_49024_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_49024_year_2020.txt')
df
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0        1101621243             S                   1               F
# 1      601763359215             S                   0               F
# 2      601537416445             S                   0               F
# 3         300927794             S                   0               F
# 4      401378841033             S                   0               F
# ...             ...           ...                 ...             ...
# 18255    1441677189             S                   1               F
# 18256  100300936735             S                   1               F
# 18257  902386068437             S                   1               F
# 18258  700300882709             S                   1               F
# 18259  800920830251             M                   1               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 55319

# %%
df_55319 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_55319_year_2020.txt', sep = '\t')
df_55319
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0         56450419             S                   1               F
# 1        238018586             S                   1               F
# 2        238566801             S                   1               F
# 3        238582990             S                   0               F
# 4        238677533             S                   1               F
# ...            ...           ...                 ...             ...
# 2911  902464052099             S                   1               F
# 2912  902464052117             S                   0               F
# 2913  902464052125             S                   0               F
# 2914  902464052133             S                   0               F
# 2915  902464099413             U                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_55319 = df_55319.sample(frac=1)
df_55319
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 1919  601758112913             S                   1               F
# 344   100238848038             S                   1               F
# 1365  402217313845             S                   1               F
# 2617  900238843192             S                   1               F
# 362   100238848363             S                   1               F
# ...            ...           ...                 ...             ...
# 1870  600890321681             S                   1               F
# 3        238582990             S                   0               F
# 2394  800238838781             S                   1               F
# 1060  301158380790             S                   1               F
# 2697  900238848532             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_55319.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_55319_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_55319_year_2020.txt')
df
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0     601758112913             S                   1               F
# 1     100238848038             S                   1               F
# 2     402217313845             S                   1               F
# 3     900238843192             S                   1               F
# 4     100238848363             S                   1               F
# ...            ...           ...                 ...             ...
# 2911  600890321681             S                   1               F
# 2912     238582990             S                   0               F
# 2913  800238838781             S                   1               F
# 2914  301158380790             S                   1               F
# 2915  900238848532             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 96784

# %%
df_96784 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_96784_year_2020.txt', sep = '\t')
df_96784
# Out:
#          FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0         1949801             U                   1               F
# 1        27708780             U                   1               F
# 2        27709477             U                   1               F
# 3        27709508             U                   1               F
# 4        27709566             U                   1               F
# ..            ...           ...                 ...             ...
# 408  902366515127             U                   1               F
# 409  902422921095             U                   0               F
# 410  902422921105             U                   1               F
# 411  902422921113             U                   0               F
# 412  902422921121             U                   1               F
#
#      tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_96784 = df_96784.sample(frac=1)
df_96784
# Out:
#          FamilyID location_type  primary_family_ind HouseholdStatus  \
# 345  800607320244             U                   1               F
# 339  800391105130             U                   1               F
# 259  600027708937             U                   0               F
# 74   102269119853             U                   1               F
# 265  600027709551             U                   1               F
# ..            ...           ...                 ...             ...
# 206  401447908209             U                   1               F
# 185  400027708850             U                   1               F
# 108  200969402308             U                   1               F
# 261  600027709056             U                   1               F
# 363  801884802079             U                   1               F
#
#      tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_96784.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_96784_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_96784_year_2020.txt')
df
# Out:
#          FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0    800607320244             U                   1               F
# 1    800391105130             U                   1               F
# 2    600027708937             U                   0               F
# 3    102269119853             U                   1               F
# 4    600027709551             U                   1               F
# ..            ...           ...                 ...             ...
# 408  401447908209             U                   1               F
# 409  400027708850             U                   1               F
# 410  200969402308             U                   1               F
# 411  600027709056             U                   1               F
# 412  801884802079             U                   1               F
#
#      tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 49232

# %%
df_49232 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_49232_year_2020.txt', sep = '\t')
df_49232
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0        271979924             U                   1               F
# 1        291516782             S                   1               F
# 2        293511876             S                   1               F
# 3        300275834             S                   1               F
# 4        300459967             S                   1               F
# ...            ...           ...                 ...             ...
# 1552  902443227929             S                   0               F
# 1553  902443227937             S                   1               F
# 1554  902443227945             U                   0               F
# 1555  902470934155             S                   1               F
# 1556  902470934163             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_49232 = df_49232.sample(frac=1)
df_49232
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 375   201334312183             U                   0               F
# 125     2434292273             S                   0               F
# 1187  701812392759             S                   0               F
# 1263  800302876474             S                   1               F
# 362   201101519228             S                   0               F
# ...            ...           ...                 ...             ...
# 1321  800999455958             S                   0               F
# 1482  901158473245             S                   0               F
# 1046  700292572260             S                   1               F
# 1456  900533223751             S                   1               F
# 30       380363105             U                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_49232.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_49232_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_49232_year_2020.txt')
df
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0     201334312183             U                   0               F
# 1       2434292273             S                   0               F
# 2     701812392759             S                   0               F
# 3     800302876474             S                   1               F
# 4     201101519228             S                   0               F
# ...            ...           ...                 ...             ...
# 1552  800999455958             S                   0               F
# 1553  901158473245             S                   0               F
# 1554  700292572260             S                   1               F
# 1555  900533223751             S                   1               F
# 1556     380363105             U                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 90275

# %%
df_90275 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_90275_year_2020.txt', sep = '\t')
df_90275
# Out:
# /tmp/ipykernel_4095284/3704659162.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_90275 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_90275_year_2020.txt', sep = '\t')
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0            443758             S                   1               F
# 1           3389073             S                   1               F
# 2          26263761             S                   1               F
# 3          28225477             S                   1               F
# 4          30070788             M                   0               F
# ...             ...           ...                 ...             ...
# 24306  902472514131             S                   1               F
# 24307  902472514149             S                   0               F
# 24308  902472514157             S                   0               F
# ...

# %%
df_90275 = df_90275.sample(frac=1)
df_90275
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 22309  900109709372             S                   0               S
# 17002  700108332041             S                   1               F
# 2414     2448972791             S                   0               F
# 5546   200109732998             S                   0               F
# 3951   101129215784             S                   0               F
# ...             ...           ...                 ...             ...
# 3949   101124553335             S                   0               F
# 4053   101258714665             M                   1               F
# 2988   100109720394             S                   1               F
# 13136  500114126691             S                   1               F
# 10375  400109732693             S                   1               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_90275.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_90275_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_90275_year_2020.txt')
df
# Out:
# /tmp/ipykernel_4095284/771487368.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_90275_year_2020.txt')
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0      900109709372             S                   0               S
# 1      700108332041             S                   1               F
# 2        2448972791             S                   0               F
# 3      200109732998             S                   0               F
# 4      101129215784             S                   0               F
# ...             ...           ...                 ...             ...
# 24306  101124553335             S                   0               F
# 24307  101258714665             M                   1               F
# 24308  100109720394             S                   1               F
# ...

# %% [markdown]
# #### Zip 24148

# %%
df_24148 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_24148_year_2020.txt', sep = '\t')
df_24148
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0          8048940             S                   0               F
# 1          9087855             S                   0               F
# 2         12304313             S                   0               F
# 3         12304321             S                   0               F
# 4         12304333             S                   0               F
# ...            ...           ...                 ...             ...
# 4846  902460254705             S                   1               F
# 4847  902460254721             S                   1               F
# 4848  902460254739             S                   1               F
# 4849  902460254747             S                   1               F
# 4850  902460254865             U                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_24148 = df_24148.sample(frac=1)
df_24148
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 2646  500013235014             S                   1               F
# 2825  501821001687             S                   1               F
# 3836  701961328775             S                   0               F
# 258     1472565411             S                   1               F
# 4617  900877344168             S                   0               F
# ...            ...           ...                 ...             ...
# 3618  700404839186             S                   1               F
# 2423  500013125286             S                   1               F
# 4844  902428563839             S                   0               F
# 2079  400048428147             S                   1               F
# 4785  902195397687             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_24148.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_24148_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_24148_year_2020.txt')
df
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0     500013235014             S                   1               F
# 1     501821001687             S                   1               F
# 2     701961328775             S                   0               F
# 3       1472565411             S                   1               F
# 4     900877344168             S                   0               F
# ...            ...           ...                 ...             ...
# 4846  700404839186             S                   1               F
# 4847  500013125286             S                   1               F
# 4848  902428563839             S                   0               F
# 4849  400048428147             S                   1               F
# 4850  902195397687             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 73107

# %%
df_73107 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_73107_year_2020.txt', sep = '\t')
df_73107
# Out:
# /tmp/ipykernel_4095284/818847994.py:1: DtypeWarning: Columns (21,51,52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_73107 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_73107_year_2020.txt', sep = '\t')
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0           1361306             S                   1               F
# 1          65076697             S                   0               F
# 2          65475093             S                   1               F
# 3         106567705             S                   1               F
# 4         109068918             S                   1               F
# ...             ...           ...                 ...             ...
# 16757  902473619145             S                   0               F
# 16758  902473619543             S                   1               F
# ...

# %%
df_73107 = df_73107.sample(frac=1)
df_73107
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 4212   201539985111             M                   0               F
# 9332   501443026771             M                   1               F
# 2764   101906319057             S                   1               F
# 16192  901881829057             S                   0               F
# 10531  600859153149             S                   1               F
# ...             ...           ...                 ...             ...
# 1512     2418871307             S                   1               F
# 9636   502144115279             M                   1               F
# 3784   200717893237             S                   1               F
# 2942   102205116783             S                   1               F
# 11094  601914758303             S                   0               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_73107.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_73107_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_73107_year_2020.txt')
df
# Out:
# /tmp/ipykernel_4095284/1962900173.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_73107_year_2020.txt')
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0      201539985111             M                   0               F
# 1      501443026771             M                   1               F
# 2      101906319057             S                   1               F
# 3      901881829057             S                   0               F
# 4      600859153149             S                   1               F
# ...             ...           ...                 ...             ...
# 16757    2418871307             S                   1               F
# 16758  502144115279             M                   1               F
# 16759  200717893237             S                   1               F
# ...

# %% [markdown]
# #### Zip 48412

# %%
df_48412 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_48412_year_2020.txt', sep = '\t')
df_48412
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0         65163546             S                   1               F
# 1        271287304             S                   1               F
# 2        283297261             S                   1               F
# 3        283897490             S                   0               F
# 4        284518719             S                   0               F
# ...            ...           ...                 ...             ...
# 3336  902463579273             S                   1               F
# 3337  902470930415             S                   1               F
# 3338  902470930423             S                   1               F
# 3339  902470930431             S                   0               F
# 3340  902470930753             U                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_48412 = df_48412.sample(frac=1)
df_48412
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 2416  700295983827             S                   1               F
# 622   102180400499             S                   0               F
# 1947  502232844631             S                   0               F
# 2525  701079547659             S                   0               F
# 779   200626512822             S                   1               F
# ...            ...           ...                 ...             ...
# 1679  500295981311             S                   1               F
# 2240  602443125309             S                   1               F
# 1862  501101459606             S                   1               F
# 2939  900295123051             S                   1               F
# 288   100295980350             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_48412.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_48412_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_48412_year_2020.txt')
df
# Out:
#           FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0     700295983827             S                   1               F
# 1     102180400499             S                   0               F
# 2     502232844631             S                   0               F
# 3     701079547659             S                   0               F
# 4     200626512822             S                   1               F
# ...            ...           ...                 ...             ...
# 3336  500295981311             S                   1               F
# 3337  602443125309             S                   1               F
# 3338  501101459606             S                   1               F
# 3339  900295123051             S                   1               F
# 3340  100295980350             S                   1               F
#
#       tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 14086

# %%
df_14086 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_14086_year_2020.txt', sep = '\t')
df_14086
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0           1581140             S                   1               F
# 1           2660845             S                   1               F
# 2           3090573             S                   1               F
# 3          28939116             M                   1               F
# 4          46955758             S                   1               F
# ...             ...           ...                 ...             ...
# 19917  902472007111             S                   0               F
# 19918  902472007145             S                   0               F
# 19919  902472007153             S                   0               F
# 19920  902472007161             S                   0               F
# 19921  902472196813             M                   1               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_14086 = df_14086.sample(frac=1)
df_14086
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 4450   200102383490             S                   0               F
# 6467   300102395227             S                   0               F
# 6481   300102395418             S                   1               F
# 1168     1362947301             S                   0               F
# 9677   402257447347             M                   1               F
# ...             ...           ...                 ...             ...
# 7239   301241534525             S                   0               F
# 7479   301805756059             S                   1               F
# 15130  701256172049             S                   0               F
# 18060  900102377503             S                   1               F
# 17658  802417409893             S                   0               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_14086.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_14086_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_14086_year_2020.txt')
df
# Out:
#            FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0      200102383490             S                   0               F
# 1      300102395227             S                   0               F
# 2      300102395418             S                   1               F
# 3        1362947301             S                   0               F
# 4      402257447347             M                   1               F
# ...             ...           ...                 ...             ...
# 19917  301241534525             S                   0               F
# 19918  301805756059             S                   1               F
# 19919  701256172049             S                   0               F
# 19920  900102377503             S                   1               F
# 19921  802417409893             S                   0               F
#
#        tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %% [markdown]
# #### Zip 77255

# %%
df_77255 = pd.read_csv('/hpc/group/codeplus22-vis/infousa_copy/2020/Household_Ethnicity_zip_77255_year_2020.txt', sep = '\t')
df_77255
# Out:
#          FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0        27450991             U                   1               F
# 1       195789848             U                   0               F
# 2       220222611             U                   1               F
# 3       335299334             U                   1               F
# 4       338641348             U                   1               F
# ..            ...           ...                 ...             ...
# 415  902404789105             U                   1               F
# 416  902431272069             U                   0               F
# 417  902431272475             U                   1               F
# 418  902431272577             U                   0               F
# 419  902431272705             U                   1               F
#
#      tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_77255 = df_77255.sample(frac=1)
df_77255
# Out:
#          FamilyID location_type  primary_family_ind HouseholdStatus  \
# 333  800336027979             U                   1               S
# 258  600428575679             U                   0               F
# 144  301210911261             U                   1               F
# 16      961422539             U                   1               F
# 142  301002522537             U                   1               F
# ..            ...           ...                 ...             ...
# 76   102357193323             U                   1               F
# 198  402468530077             U                   1               F
# 267  601294896835             U                   1               F
# 345  800552643607             U                   1               F
# 391  900999530369             U                   1               F
#
#      tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...

# %%
df_77255.to_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_77255_year_2020.txt', index = False)

# %%
df = pd.read_csv('/hpc/group/codeplus22-vis/synthetic_data/synthetic_infousa/Household_Ethnicity_zip_77255_year_2020.txt')
df
# Out:
#          FamilyID location_type  primary_family_ind HouseholdStatus  \
# 0    800336027979             U                   1               S
# 1    600428575679             U                   0               F
# 2    301210911261             U                   1               F
# 3       961422539             U                   1               F
# 4    301002522537             U                   1               F
# ..            ...           ...                 ...             ...
# 415  102357193323             U                   1               F
# 416  402468530077             U                   1               F
# 417  601294896835             U                   1               F
# 418  800552643607             U                   1               F
# 419  900999530369             U                   1               F
#
#      tradeline_count head_hh_age_code  length_of_residence  ChildrenHHCount  \
# ...
