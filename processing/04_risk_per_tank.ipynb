# %% [markdown]
# # Performing Spatial Joins to Find Intersecting Geometries
# ### Classifying tanks by whether or not they lie on floodplains, and merging with National Risk Index Data

# %% [markdown]
# ### Import statements

# %%
import os
import pandas as pd
import geopandas as gpd
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.11.0-CAPI-1.17.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ### Reading AST Data

# %%
DATA_DIR = os.getcwd()
DATA_DIR = DATA_DIR.replace('processing', 'data')
DATA_DIR
# Out:
# '/hpc/home/at341/ondemand/codeplus-celine-dcc-package/data'

# %%
df_tanks = gpd.read_file(DATA_DIR + '/ast_master_TEST.shp')
df_tanks.head(n=3)
# Out:
#         state         tank_type  diameter  lat_t_4326  lon_t_4326  \
# 0   Wisconsin  closed_roof_tank      27.6   43.044796  -89.296132
# 1   Minnesota  closed_roof_tank      18.6   44.440530  -95.820582
# 2  California  closed_roof_tank      40.8   34.043971 -117.337983
#
#      lat_t_3857    lon_t_3857 county                     geometry
# 0 -9.940400e+06  5.318793e+06  55025   POINT (-89.29613 43.04480)
# 1 -1.066670e+07  5.533870e+06  27083   POINT (-95.82058 44.44053)
# 2 -1.306200e+07  4.034708e+06  06071  POINT (-117.33798 34.04397)

# %% [markdown]
# ### Using ```.sjoin()``` to classify tanks by whether or not they are on a floodplain

# %% [markdown]
# #### Reading floodplain data from the Federal Emergency Management Agency (FEMA)
# Then filtering for only the column we need (geometry) to find which tanks lie on a floodplain. This file was too large to include in this repository, so we randomly sampled 1% of the 1.5 million observations to get around 150,000 observations.

# %%
df_floodplains = gpd.read_file(DATA_DIR + '/nat_hazard_files/floodplain_files/floodplains.shp')
df_floodplains
# Out:
#        DFIRM_ID VERSION_ID     BFE_LN_ID    ELEV LEN_UNIT V_DATUM  \
# 0        37111C    1.1.1.0   37111C_5701   992.0     Feet  NAVD88
# 1        27139C    1.1.1.0    27139C_480   950.0     Feet  NAVD88
# 2        01073C    2.3.3.3   01073C_3287   537.0     Feet  NAVD88
# 3        22087C    1.1.1.0    22087C_215     1.0     Feet  NAVD88
# 4        42047C    1.1.1.0    42047C_510  1580.0     Feet  NAVD88
# ...         ...        ...           ...     ...      ...     ...
# 157390   37185C    1.1.1.0  37185C_39672   285.0     Feet  NAVD88
# 157391   05103C    1.1.1.0    05103C_568   135.0     Feet  NAVD88
# 157392   37193C    1.1.1.0  37193C_10884  1160.0     Feet  NAVD88
# 157393   41017C    2.1.3.0    41017C_433  3608.0     Feet  NAVD88
# 157394   210067    1.1.1.0    210067_629   874.0     Feet  NAVD88
#
#             SOURCE_CIT                                  GFID  Shape_Leng  \
# 0        37111C_STUDY4  c5ed825d-d798-4326-ac9f-521d5474ca51    0.000402
# 1          27139C_FIS1  3f07c33a-59bb-42b9-9c05-b07416b15e4d    0.000819
# 2        01073C_STUDY1  0a367dee-ddb1-479a-a068-54482dbf5059    0.001161
# 3       22087C_STUDY13  80996f13-99f4-4826-a737-86b261605b10    0.000073
# 4        42047C_STUDY2  dc310fd3-dd81-4716-b01e-d7fc042a15f7    0.001016
# ...                ...                                   ...         ...
# 157390   37185C_STUDY4  71eee819-e974-48cb-8eda-e6b254606e9f    0.002508
# 157391   05103C_STUDY1                                  None    0.001235
# 157392   37193C_STUDY4                                  None    0.000446
# 157393    41017C_LOMC5  a9aceec6-e4a8-41cc-afb3-ae12d56fa2a2    0.000664
# 157394   210067_STUDY4  139f780e-ab54-4cbc-b1cf-9257a554b151    0.001219
#
#                                                  geometry
# 0       LINESTRING (-81.85514 35.55379, -81.85481 35.5...
# 1       LINESTRING (-93.60993 44.55477, -93.61023 44.5...
# 2       LINESTRING (-86.90697 33.56901, -86.90806 33.5...
# 3       LINESTRING (-89.85064 29.86607, -89.85065 29.8...
# 4       LINESTRING (-78.64175 41.31597, -78.64266 41.3...
# ...                                                   ...
# 157390  LINESTRING (-78.08776 36.36467, -78.08749 36.3...
# 157391  LINESTRING (-92.84933 33.58808, -92.84990 33.5...
# 157392  LINESTRING (-80.91487 36.33171, -80.91481 36.3...
# 157393  LINESTRING (-121.32028 44.05004, -121.32035 44...
# 157394  LINESTRING (-84.54486 38.06954, -84.54577 38.0...
#
# [157395 rows x 10 columns]

# %%
df_floodplains = df_floodplains[['geometry']]
df_floodplains
# Out:
#                                                  geometry
# 0       LINESTRING (-81.85514 35.55379, -81.85481 35.5...
# 1       LINESTRING (-93.60993 44.55477, -93.61023 44.5...
# 2       LINESTRING (-86.90697 33.56901, -86.90806 33.5...
# 3       LINESTRING (-89.85064 29.86607, -89.85065 29.8...
# 4       LINESTRING (-78.64175 41.31597, -78.64266 41.3...
# ...                                                   ...
# 157390  LINESTRING (-78.08776 36.36467, -78.08749 36.3...
# 157391  LINESTRING (-92.84933 33.58808, -92.84990 33.5...
# 157392  LINESTRING (-80.91487 36.33171, -80.91481 36.3...
# 157393  LINESTRING (-121.32028 44.05004, -121.32035 44...
# 157394  LINESTRING (-84.54486 38.06954, -84.54577 38.0...
#
# [157395 rows x 1 columns]

# %% [markdown]
# #### Using the GeoPandas buffer function
# This way, tanks within 200 meters from either side of the floodplain will be marked as near a floodplain. As The floodplain data is given in linestring or multilinestring geometries, so buffering it provides a more generalized understanding of the tanks that are near areas of flooding risk, not only the ones directly in the line of risk.

# %% [markdown]
# In order to buffer the geometries by 200 meters, it is necessary to convert the coordinate system of the dataframe to EPSG 3857, as the unit of measurement for this coordinate system is the meter. The final coordinate system conversion sets the floodplain dataframe to the same coordinate system as the tank dataframe. This consistency is key in the next few steps.

# %%
# %%time
df_floodplains = df_floodplains.to_crs("EPSG:3857")
df_floodplains = df_floodplains.buffer(200)
df_floodplains= df_floodplains.to_crs("EPSG:4326")
df_floodplains
# Out:
# CPU times: user 6.99 s, sys: 168 ms, total: 7.16 s
# Wall time: 7.19 s
# 0         POLYGON ((-81.85592 35.55515, -81.85577 35.555...
# 1         POLYGON ((-93.61196 44.55519, -93.61196 44.555...
# 2         POLYGON ((-86.90879 33.56804, -86.90895 33.568...
# 3         POLYGON ((-89.84902 29.86540, -89.84903 29.865...
# 4         POLYGON ((-78.64366 41.31530, -78.64380 41.315...
#                                 ...
# 157390    POLYGON ((-78.08798 36.36610, -78.08644 36.366...
# 157391    POLYGON ((-92.85142 33.58805, -92.85152 33.588...
# 157392    POLYGON ((-80.91302 36.33142, -80.91301 36.331...
# 157393    POLYGON ((-121.31939 44.04892, -121.31943 44.0...
# 157394    POLYGON ((-84.54443 38.06779, -84.54456 38.067...
# Length: 157395, dtype: geometry

# %% [markdown]
# The buffer function transforms the geopandas dataframe into a geoseries, but to find which tanks lie on or near floodplains, it is necessary to convert this geoseries into a GeoDataFrame.

# %%
gdf_floodplains = gpd.GeoDataFrame(df_floodplains)
gdf_floodplains.rename(columns = {0: 'geometry'}, inplace = True)
gdf_floodplains
# Out:
#                                                  geometry
# 0       POLYGON ((-81.85592 35.55515, -81.85577 35.555...
# 1       POLYGON ((-93.61196 44.55519, -93.61196 44.555...
# 2       POLYGON ((-86.90879 33.56804, -86.90895 33.568...
# 3       POLYGON ((-89.84902 29.86540, -89.84903 29.865...
# 4       POLYGON ((-78.64366 41.31530, -78.64380 41.315...
# ...                                                   ...
# 157390  POLYGON ((-78.08798 36.36610, -78.08644 36.366...
# 157391  POLYGON ((-92.85142 33.58805, -92.85152 33.588...
# 157392  POLYGON ((-80.91302 36.33142, -80.91301 36.331...
# 157393  POLYGON ((-121.31939 44.04892, -121.31943 44.0...
# 157394  POLYGON ((-84.54443 38.06779, -84.54456 38.067...
#
# [157395 rows x 1 columns]

# %% [markdown]
# #### Finding the tanks that lie on/near floodplains using the sjoin() function

# %% [markdown]
# The GeoPandas ```.sjoin()``` function performs a spatial join of two GeoDataFrames. In this case, the predicate parameter input 'intersects' means that the output is a new GeoDataFrame containing only the rows in one GeoDataFrame whose geometries intersected those in the other GeoDataFrame. In other words, function outputs a GeoDataFrame containing only the tanks that lie within 200 meters of a floodplain.

# %%
# %%time
df_intersect = gpd.sjoin(df_tanks, gdf_floodplains, how='inner', predicate='intersects')
df_intersect.head()
# Out:
# CPU times: user 200 ms, sys: 1.95 ms, total: 202 ms
# Wall time: 201 ms
#               state           tank_type  diameter  lat_t_4326  lon_t_4326  \
# 97     Pennsylvania    closed_roof_tank      16.8   41.827905  -79.123178
# 143      New Jersey    closed_roof_tank      12.0   40.610034  -74.223491
# 272  South Carolina  sedimentation_tank      37.8   34.905740  -81.915891
# 339    Pennsylvania    closed_roof_tank      25.8   40.525380  -80.175291
# 487           Texas    closed_roof_tank       5.4   32.875772  -97.060631
#
#        lat_t_3857    lon_t_3857 county                    geometry  \
# 97  -8.807952e+06  5.135235e+06  42123  POINT (-79.12318 41.82791)
# 143 -8.262521e+06  4.954991e+06  34039  POINT (-74.22349 40.61003)
# 272 -9.118835e+06  4.151079e+06  45083  POINT (-81.91589 34.90574)
# 339 -8.925073e+06  4.942585e+06  42003  POINT (-80.17529 40.52538)
# 487 -1.080474e+07  3.878826e+06  48439  POINT (-97.06063 32.87577)
#
#      index_right
# 97        105026
# 143        91591
# 272       111984
# 339       147627
# 487        88222

# %% [markdown]
# Drop tanks with the same latitude and longitude, which are therefore duplicates:

# %%
df_intersect = df_intersect.drop_duplicates(subset = ['lat_t_4326', 'lon_t_4326'])
df_intersect.head()
# Out:
#                state                    tank_type  diameter  lat_t_4326  \
# 172    Massachusetts             closed_roof_tank      38.4   42.174907
# 223        Minnesota             closed_roof_tank      56.4   44.460883
# 306        Minnesota             closed_roof_tank      39.0   44.461186
# 307        Minnesota             closed_roof_tank      38.4   44.461530
# 225        Minnesota             closed_roof_tank      29.4   44.461631
# ...              ...                          ...       ...         ...
# 97582     California               spherical_tank      16.2   38.071334
# 97543     California  external_floating_roof_tank      72.0   38.078420
# 97545     California  external_floating_roof_tank      57.6   38.077633
# 97933        Indiana             closed_roof_tank      37.8   41.612604
# 98036       Colorado             closed_roof_tank      17.4   39.783980
#
#        lon_t_4326    lat_t_3857    lon_t_3857 county  \
# 172    -72.459486 -8.066153e+06  5.187216e+06  25013
# 223    -95.789712 -1.066326e+07  5.537044e+06  27083
# 306    -95.788919 -1.066317e+07  5.537091e+06  27083
# 307    -95.788675 -1.066315e+07  5.537145e+06  27083
# 225    -95.789517 -1.066324e+07  5.537161e+06  27083
# ...           ...           ...           ...    ...
# 97582 -122.134249 -1.359592e+07  4.589508e+06  06095
# 97543 -122.139659 -1.359652e+07  4.590510e+06  06095
# 97545 -122.139285 -1.359648e+07  4.590399e+06  06095
# 97933  -87.462867 -9.736322e+06  5.103125e+06  18089
# 98036 -104.905330 -1.167801e+07  4.834600e+06  08001
#
#                                                 geometry  index_right
# 172    POLYGON ((-72.45971 42.17509, -72.45926 42.175...       503713
# 223    POLYGON ((-95.79010 44.46113, -95.78932 44.461...       542889
# 306    POLYGON ((-95.78918 44.46136, -95.78866 44.461...       542889
# 307    POLYGON ((-95.78895 44.46170, -95.78840 44.461...       542889
# 225    POLYGON ((-95.78976 44.46176, -95.78927 44.461...       542577
# ...                                                  ...          ...
# 97582  POLYGON ((-122.13434 38.07141, -122.13416 38.0...       160165
# 97543  POLYGON ((-122.14008 38.07875, -122.13924 38.0...       160191
# 97545  POLYGON ((-122.13964 38.07789, -122.13893 38.0...       160191
# 97933  POLYGON ((-87.46314 41.61277, -87.46260 41.612...       385506
# 98036  POLYGON ((-104.90549 39.78406, -104.90517 39.7...       172211
#
# [6609 rows x 10 columns]

# %% [markdown]
# #### Using ```df_intersect``` to classify the tanks in the original dataset

# %%
idx = list(df_intersect.index.values)
# Out:
# 6609

# %%
# %%time
df_tanks['on_floodplain'] = 0

for num in idx:
    df_tanks['on_floodplain'].iloc[num] = 1
    
df_tanks
# Out:
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 637 ms, sys: 2.03 ms, total: 639 ms
# Wall time: 641 ms
#           state                tank_type  diameter  lat_t_4326  lon_t_4326  \
# 0      New York         closed_roof_tank      39.6   40.625572  -73.745231
# 1      New York         closed_roof_tank      19.8   40.624761  -73.744420
# 2      New York         closed_roof_tank      12.6   40.626086  -73.746257
# 3      New York         closed_roof_tank      30.6   40.625786  -73.746203
# 4      New York         closed_roof_tank      24.0   40.625781  -73.745813
# ...         ...                      ...       ...         ...         ...
# 98164  Colorado  narrow_closed_roof_tank       5.4   39.777431 -104.920718
# 98165  Colorado  narrow_closed_roof_tank       4.8   39.777301 -104.920631
# 98166  Colorado  narrow_closed_roof_tank       3.6   39.777701 -104.920609
# 98167  Colorado  narrow_closed_roof_tank       4.8   39.776628 -104.920617
# 98168  Colorado  narrow_closed_roof_tank       4.8   39.776625 -104.920673
#
#          lat_t_3857    lon_t_3857 county  \
# 0     -8.209282e+06  4.957270e+06  36059
# 1     -8.209191e+06  4.957151e+06  36059
# 2     -8.209396e+06  4.957345e+06  36059
# 3     -8.209390e+06  4.957301e+06  36059
# 4     -8.209346e+06  4.957300e+06  36059
# ...             ...           ...    ...
# 98164 -1.167972e+07  4.833652e+06  08031
# 98165 -1.167971e+07  4.833633e+06  08031
# 98166 -1.167971e+07  4.833691e+06  08031
# 98167 -1.167971e+07  4.833535e+06  08031
# 98168 -1.167972e+07  4.833535e+06  08031
#
#                                                 geometry  on_floodplain
# 0      POLYGON ((-73.74547 40.62575, -73.74500 40.625...              0
# 1      POLYGON ((-73.74465 40.62485, -73.74419 40.624...              0
# 2      POLYGON ((-73.74633 40.62615, -73.74618 40.626...              0
# 3      POLYGON ((-73.74639 40.62593, -73.74601 40.625...              0
# 4      POLYGON ((-73.74595 40.62590, -73.74567 40.625...              0
# ...                                                  ...            ...
# 98164  POLYGON ((-104.92075 39.77746, -104.92069 39.7...              0
# 98165  POLYGON ((-104.92066 39.77732, -104.92060 39.7...              0
# 98166  POLYGON ((-104.92064 39.77772, -104.92058 39.7...              0
# 98167  POLYGON ((-104.92065 39.77665, -104.92059 39.7...              0
# 98168  POLYGON ((-104.92070 39.77665, -104.92065 39.7...              0
#
# [98169 rows x 10 columns]

# %% [markdown]
# Now, our original tanks dataframe, ```df_tanks``` has a column indicating whether or not that tank is near a floodplain.

# %% [markdown]
# ### Reading National Risk Index Data, taken from FEMA
# We want to classify each tank by its risk from a variet of natural hazards. To do this, we read in NRI data, filter for only the columns we want, as stipulated by our researcher, and rename them for standardization purposes.

# %%
df_nri = gpd.read_file('/hpc/group/codeplus22-vis/NRI_Data/NRI_GDB_Counties.gdb')
df_nri.head()
# Out:
#       NRI_ID     STATE STATEABBRV STATEFIPS      COUNTY COUNTYTYPE COUNTYFIPS  \
# 0     C21115  Kentucky         KY        21     Johnson     County        115
# 1     C21117  Kentucky         KY        21      Kenton     County        117
# 2     C21119  Kentucky         KY        21       Knott     County        119
# 3     C21121  Kentucky         KY        21        Knox     County        121
# 4     C21123  Kentucky         KY        21       Larue     County        123
# ...      ...       ...        ...       ...         ...        ...        ...
# 3137  C56037   Wyoming         WY        56  Sweetwater     County        037
# 3138  C56039   Wyoming         WY        56       Teton     County        039
# 3139  C56041   Wyoming         WY        56       Uinta     County        041
# 3140  C56043   Wyoming         WY        56    Washakie     County        043
# 3141  C56045   Wyoming         WY        56      Weston     County        045
#
#      STCOFIPS  POPULATION    BUILDVALUE  ...   WNTW_EALA     WNTW_EALT  \
# 0       21115       23356  1.924008e+09  ...    4.235939  47363.199731
# 1       21117      159720  1.877338e+10  ...   44.606252  64259.532691
# 2       21119       16346  1.170376e+09  ...    0.023091  30809.754620
# 3       21121       31883  2.135773e+09  ...    0.082573  61427.308851
# 4       21123       14193  1.221343e+09  ...  246.668438  12870.385216
# ...       ...         ...           ...  ...         ...           ...
# 3137    56037       43806  4.583896e+09  ...    0.000041  23921.162465
# 3138    56039       21294  3.476594e+09  ...    0.000078  10806.759196
# 3139    56041       21118  2.018844e+09  ...   27.256486  77290.242488
# 3140    56043        8533  8.867450e+08  ...    1.415514   5466.737290
# 3141    56045        7208  7.744440e+08  ...    6.880699  39946.691949
#
#       WNTW_EALS            WNTW_EALR  WNTW_RISKS           WNTW_RISKR  \
# 0     19.448529  Relatively Moderate   14.131237       Relatively Low
# 1     21.530408  Relatively Moderate   12.470040       Relatively Low
# 2     16.851393       Relatively Low   14.466270       Relatively Low
# 3     21.209328  Relatively Moderate   19.585915  Relatively Moderate
# 4     12.597091       Relatively Low    7.715952             Very Low
# ...         ...                  ...         ...                  ...
# 3137  15.488184       Relatively Low    5.189094             Very Low
# 3138  11.884244       Relatively Low    4.816165             Very Low
# 3139  22.897143  Relatively Moderate   11.296648       Relatively Low
# 3140   9.469255             Very Low    8.193083             Very Low
# 3141  18.375254       Relatively Low   10.777060       Relatively Low
#
#             NRI_VER   Shape_Length    Shape_Area  \
# 0     November 2021  190441.334565  1.098944e+09
# 1     November 2021  140730.907028  7.042492e+08
# 2     November 2021  211206.226178  1.448900e+09
# 3     November 2021  237214.255701  1.572984e+09
# 4     November 2021  226736.665860  1.088060e+09
# ...             ...            ...           ...
# 3137  November 2021  948276.037782  4.872259e+10
# 3138  November 2021  693578.042491  2.106945e+10
# 3139  November 2021  394529.654192  9.587253e+09
# 3140  November 2021  530268.728571  1.119277e+10
# 3141  November 2021  437744.044699  1.195223e+10
#
#                                                geometry
# 0     MULTIPOLYGON (((-9196369.959 4562386.043, -919...
# 1     MULTIPOLYGON (((-9407183.321 4735315.123, -940...
# 2     MULTIPOLYGON (((-9233790.126 4509476.801, -923...
# 3     MULTIPOLYGON (((-9305143.376 4432946.710, -930...
# 4     MULTIPOLYGON (((-9520186.985 4516660.323, -952...
# ...                                                 ...
# 3137  MULTIPOLYGON (((-12138708.678 5200561.200, -12...
# 3138  MULTIPOLYGON (((-12251065.165 5466684.703, -12...
# 3139  MULTIPOLYGON (((-12250488.599 5097977.175, -12...
# 3140  MULTIPOLYGON (((-11927529.355 5491116.330, -11...
# 3141  MULTIPOLYGON (((-11583293.675 5493400.221, -11...
#
# [3142 rows x 367 columns]

# %%
df_nri = df_nri[['STCOFIPS', 'ERQK_RISKS', 'SWND_RISKS', 'HRCN_RISKS', 'TRND_RISKS', 'CFLD_RISKS', 'RFLD_RISKS']]
df_nri.rename(columns = {'STCOFIPS': 'county', 'ERQK_RISKS': 'erqk_risks', 'SWND_RISKS': 'swnd_risks', 'HRCN_RISKS': 'hrcn_risks', 
                         'TRND_RISKS': 'trnd_risks', 'CFLD_RISKS': 'cfld_risks', 'RFLD_RISKS': 'rfld_risks'}, inplace = True)
df_nri
# Out:
# /tmp/ipykernel_320985/4053087610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nri.rename(columns = {'STCOFIPS': 'county', 'ERQK_RISKS': 'erqk_risks', 'SWND_RISKS': 'swnd_risks', 'HRCN_RISKS': 'hrcn_risks',
#      county  erqk_risks  swnd_risks  hrcn_risks  trnd_risks  cfld_risks  \
# 0     21115    1.953248   10.756017    1.668058    9.136885         NaN
# 1     21117    3.346640   19.688303    1.875497   24.280149         NaN
# 2     21119    2.281739   12.431024    1.129109   10.174559         NaN
# 3     21121    4.385020   17.589118    1.962140   19.273345         NaN
# 4     21123    2.042402   11.899304    2.473315    9.216597         NaN
# ...     ...         ...         ...         ...         ...         ...
# 3137  56037    2.070342    2.848189         NaN    2.191509         NaN
# 3138  56039    4.292420    3.143585         NaN    6.133900         NaN
# 3139  56041    3.206560    4.959357         NaN    4.118598         NaN
# 3140  56043    3.156933    6.009518         NaN    8.577072         NaN
# 3141  56045    0.849140    6.509292         NaN    6.628720         NaN
#
#       rfld_risks
# 0      14.575572
# 1       8.279166
# 2       8.755275
# 3      14.443835
# 4       4.055177
# ...          ...
# 3137    3.318171
# 3138    2.734316
# 3139    3.201339
# 3140    4.954794
# 3141    3.113188
#
# [3142 rows x 7 columns]

# %% [markdown]
# Then, we merge this ```df_nri``` dataframe with our ```df_tanks``` dataframe, based on the ```county``` column. Therefore, tanks are associated with risks from each natural hazard based on the county in which it is located.

# %% [markdown]
# ### Merging AST and NRI data using pandas' ```.merge()```

# %%
df_tank_risks = df_tanks.merge(df_nri, on = 'county', how = 'left')
df_tank_risks.head()
# Out:
#           state                tank_type  diameter  lat_t_4326  lon_t_4326  \
# 0      New York         closed_roof_tank      39.6   40.625572  -73.745231
# 1      New York         closed_roof_tank      19.8   40.624761  -73.744420
# 2      New York         closed_roof_tank      12.6   40.626086  -73.746257
# 3      New York         closed_roof_tank      30.6   40.625786  -73.746203
# 4      New York         closed_roof_tank      24.0   40.625781  -73.745813
# ...         ...                      ...       ...         ...         ...
# 98164  Colorado  narrow_closed_roof_tank       5.4   39.777431 -104.920718
# 98165  Colorado  narrow_closed_roof_tank       4.8   39.777301 -104.920631
# 98166  Colorado  narrow_closed_roof_tank       3.6   39.777701 -104.920609
# 98167  Colorado  narrow_closed_roof_tank       4.8   39.776628 -104.920617
# 98168  Colorado  narrow_closed_roof_tank       4.8   39.776625 -104.920673
#
#          lat_t_3857    lon_t_3857 county  \
# 0     -8.209282e+06  4.957270e+06  36059
# 1     -8.209191e+06  4.957151e+06  36059
# 2     -8.209396e+06  4.957345e+06  36059
# 3     -8.209390e+06  4.957301e+06  36059
# 4     -8.209346e+06  4.957300e+06  36059
# ...             ...           ...    ...
# 98164 -1.167972e+07  4.833652e+06  08031
# 98165 -1.167971e+07  4.833633e+06  08031
# 98166 -1.167971e+07  4.833691e+06  08031
# 98167 -1.167971e+07  4.833535e+06  08031
# 98168 -1.167972e+07  4.833535e+06  08031
#
#                                                 geometry  on_floodplain  \
# 0      POLYGON ((-73.74547 40.62575, -73.74500 40.625...              0
# 1      POLYGON ((-73.74465 40.62485, -73.74419 40.624...              0
# 2      POLYGON ((-73.74633 40.62615, -73.74618 40.626...              0
# 3      POLYGON ((-73.74639 40.62593, -73.74601 40.625...              0
# 4      POLYGON ((-73.74595 40.62590, -73.74567 40.625...              0
# ...                                                  ...            ...
# 98164  POLYGON ((-104.92075 39.77746, -104.92069 39.7...              0
# 98165  POLYGON ((-104.92066 39.77732, -104.92060 39.7...              0
# 98166  POLYGON ((-104.92064 39.77772, -104.92058 39.7...              0
# 98167  POLYGON ((-104.92065 39.77665, -104.92059 39.7...              0
# 98168  POLYGON ((-104.92070 39.77665, -104.92065 39.7...              0
#
#        erqk_risks  swnd_risks  hrcn_risks  trnd_risks  cfld_risks  rfld_risks
# 0        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 1        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 2        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 3        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 4        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# ...           ...         ...         ...         ...         ...         ...
# 98164    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98165    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98166    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98167    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98168    7.743007   12.625942         NaN   45.758161         NaN    6.179840
#
# [98169 rows x 16 columns]

# %% [markdown]
# ### Calculating average risk and handling NaN values
# We noticed the NRI data had a significant amount of NaN values, indicated that there is no information for that cell. Dropping all the rows with NaN values would eliminate two-thirds of our data. However, we noticed that NaN values were generally inputted for counties that had little to no risk for that specific natural hazards- counties in the center of the US had NaN values for the coastal flooding risk, for example. Therefore, after discussion with our researcher, we decided to calculate the average risk using ```0``` as the value for all NaN values, but then fill all the NaN values as ```-1```, an implausible number, to indicate in our visualizations that these values were unavailable.
#
# To do this, we made a copy of the original ```df_tank_risks```, which had all the tank information, with natural hazard risks associated to each tank. Then, we filled NaN values of the copy of that dataframe, ```df_tank_risks_calc```, with the value ```0```. This is the dataframe we used to calculate the average risk for each tank, by adding all the risk indices and dividing it by the number of natural hazards (6). We also calculated ```adj_risk```, which is the average risk for the tank, adjusted for whether or not that tank lies near a floodplain. For this column, we added five points to the ```avg_risk``` if the tank was near a floodplain, using the ```on_floodplain``` column.
#
# We also dropped all columns other than ```avg_risk``` and ```adj_risk```, because we will then merge this dataframe with the original ```df_tank_risks``` dataframe so that for each tank, we have risk indices for each individual natural hazards, along with these computed risks.

# %%
df_tank_risks_calc = df_tank_risks
df_tank_risks_calc = tank_risks_calc.fillna(0)
df_tank_risks_calc['avg_risk'] = (df_tank_risks_calc['erqk_risks'] + df_tank_risks_calc['swnd_risks'] + 
                               df_tank_risks_calc['hrcn_risks'] + df_tank_risks_calc['trnd_risks'] + 
                               df_tank_risks_calc['cfld_risks'] + df_tank_risks_calc['rfld_risks']) / 6
df_tank_risks_calc['adj_risk'] = df_tank_risks_calc['avg_risk'] + (5 * df_tank_risks_calc['on_floodplain'])
df_tank_risks_calc = df_tank_risks_calc[['avg_risk', 'adj_risk']]
df_tank_risks_calc
# Out:
#         avg_risk   adj_risk
# 0      10.050825  10.050825
# 1      10.050825  10.050825
# 2      10.050825  10.050825
# 3      10.050825  10.050825
# 4      10.050825  10.050825
# ...          ...        ...
# 98164  12.051158  12.051158
# 98165  12.051158  12.051158
# 98166  12.051158  12.051158
# 98167  12.051158  12.051158
# 98168  12.051158  12.051158
#
# [98169 rows x 2 columns]

# %%
tank_risks_merged = pd.merge(tank_risks, tank_risks_calc, left_index = True, right_index = True)
tank_risks_merged
# Out:
#           state                tank_type  diameter  lat_t_4326  lon_t_4326  \
# 0      New York         closed_roof_tank      39.6   40.625572  -73.745231
# 1      New York         closed_roof_tank      19.8   40.624761  -73.744420
# 2      New York         closed_roof_tank      12.6   40.626086  -73.746257
# 3      New York         closed_roof_tank      30.6   40.625786  -73.746203
# 4      New York         closed_roof_tank      24.0   40.625781  -73.745813
# ...         ...                      ...       ...         ...         ...
# 98164  Colorado  narrow_closed_roof_tank       5.4   39.777431 -104.920718
# 98165  Colorado  narrow_closed_roof_tank       4.8   39.777301 -104.920631
# 98166  Colorado  narrow_closed_roof_tank       3.6   39.777701 -104.920609
# 98167  Colorado  narrow_closed_roof_tank       4.8   39.776628 -104.920617
# 98168  Colorado  narrow_closed_roof_tank       4.8   39.776625 -104.920673
#
#          lat_t_3857    lon_t_3857 county  \
# 0     -8.209282e+06  4.957270e+06  36059
# 1     -8.209191e+06  4.957151e+06  36059
# 2     -8.209396e+06  4.957345e+06  36059
# 3     -8.209390e+06  4.957301e+06  36059
# 4     -8.209346e+06  4.957300e+06  36059
# ...             ...           ...    ...
# 98164 -1.167972e+07  4.833652e+06  08031
# 98165 -1.167971e+07  4.833633e+06  08031
# 98166 -1.167971e+07  4.833691e+06  08031
# 98167 -1.167971e+07  4.833535e+06  08031
# 98168 -1.167972e+07  4.833535e+06  08031
#
#                                                 geometry  on_floodplain  \
# 0      POLYGON ((-73.74547 40.62575, -73.74500 40.625...              0
# 1      POLYGON ((-73.74465 40.62485, -73.74419 40.624...              0
# 2      POLYGON ((-73.74633 40.62615, -73.74618 40.626...              0
# 3      POLYGON ((-73.74639 40.62593, -73.74601 40.625...              0
# 4      POLYGON ((-73.74595 40.62590, -73.74567 40.625...              0
# ...                                                  ...            ...
# 98164  POLYGON ((-104.92075 39.77746, -104.92069 39.7...              0
# 98165  POLYGON ((-104.92066 39.77732, -104.92060 39.7...              0
# 98166  POLYGON ((-104.92064 39.77772, -104.92058 39.7...              0
# 98167  POLYGON ((-104.92065 39.77665, -104.92059 39.7...              0
# 98168  POLYGON ((-104.92070 39.77665, -104.92065 39.7...              0
#
#        erqk_risks  swnd_risks  hrcn_risks  trnd_risks  cfld_risks  rfld_risks  \
# 0        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 1        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 2        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 3        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 4        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# ...           ...         ...         ...         ...         ...         ...
# 98164    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98165    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98166    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98167    7.743007   12.625942         NaN   45.758161         NaN    6.179840
# 98168    7.743007   12.625942         NaN   45.758161         NaN    6.179840
#
#         avg_risk   adj_risk
# 0      10.050825  10.050825
# 1      10.050825  10.050825
# 2      10.050825  10.050825
# 3      10.050825  10.050825
# 4      10.050825  10.050825
# ...          ...        ...
# 98164  12.051158  12.051158
# 98165  12.051158  12.051158
# 98166  12.051158  12.051158
# 98167  12.051158  12.051158
# 98168  12.051158  12.051158
#
# [98169 rows x 18 columns]

# %% [markdown]
# Finally, we fill in the NaN values for the risk data with -1, as discussed previously, and save this dataframe as a shapefile.

# %%
values = {"erqk_risks": -1, "swnd_risks": -1, "hrcn_risks": -1, "trnd_risks": -1, "cfld_risks": -1, "rfld_risks": -1}
tank_risks_merged = tank_risks_merged.fillna(value=values)
tank_risks_merged
# Out:
#           state                tank_type  diameter  lat_t_4326  lon_t_4326  \
# 0      New York         closed_roof_tank      39.6   40.625572  -73.745231
# 1      New York         closed_roof_tank      19.8   40.624761  -73.744420
# 2      New York         closed_roof_tank      12.6   40.626086  -73.746257
# 3      New York         closed_roof_tank      30.6   40.625786  -73.746203
# 4      New York         closed_roof_tank      24.0   40.625781  -73.745813
# ...         ...                      ...       ...         ...         ...
# 98164  Colorado  narrow_closed_roof_tank       5.4   39.777431 -104.920718
# 98165  Colorado  narrow_closed_roof_tank       4.8   39.777301 -104.920631
# 98166  Colorado  narrow_closed_roof_tank       3.6   39.777701 -104.920609
# 98167  Colorado  narrow_closed_roof_tank       4.8   39.776628 -104.920617
# 98168  Colorado  narrow_closed_roof_tank       4.8   39.776625 -104.920673
#
#          lat_t_3857    lon_t_3857 county  \
# 0     -8.209282e+06  4.957270e+06  36059
# 1     -8.209191e+06  4.957151e+06  36059
# 2     -8.209396e+06  4.957345e+06  36059
# 3     -8.209390e+06  4.957301e+06  36059
# 4     -8.209346e+06  4.957300e+06  36059
# ...             ...           ...    ...
# 98164 -1.167972e+07  4.833652e+06  08031
# 98165 -1.167971e+07  4.833633e+06  08031
# 98166 -1.167971e+07  4.833691e+06  08031
# 98167 -1.167971e+07  4.833535e+06  08031
# 98168 -1.167972e+07  4.833535e+06  08031
#
#                                                 geometry  on_floodplain  \
# 0      POLYGON ((-73.74547 40.62575, -73.74500 40.625...              0
# 1      POLYGON ((-73.74465 40.62485, -73.74419 40.624...              0
# 2      POLYGON ((-73.74633 40.62615, -73.74618 40.626...              0
# 3      POLYGON ((-73.74639 40.62593, -73.74601 40.625...              0
# 4      POLYGON ((-73.74595 40.62590, -73.74567 40.625...              0
# ...                                                  ...            ...
# 98164  POLYGON ((-104.92075 39.77746, -104.92069 39.7...              0
# 98165  POLYGON ((-104.92066 39.77732, -104.92060 39.7...              0
# 98166  POLYGON ((-104.92064 39.77772, -104.92058 39.7...              0
# 98167  POLYGON ((-104.92065 39.77665, -104.92059 39.7...              0
# 98168  POLYGON ((-104.92070 39.77665, -104.92065 39.7...              0
#
#        erqk_risks  swnd_risks  hrcn_risks  trnd_risks  cfld_risks  rfld_risks  \
# 0        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 1        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 2        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 3        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# 4        6.887656   14.447002    4.095282   13.081208    6.959016   14.834784
# ...           ...         ...         ...         ...         ...         ...
# 98164    7.743007   12.625942   -1.000000   45.758161   -1.000000    6.179840
# 98165    7.743007   12.625942   -1.000000   45.758161   -1.000000    6.179840
# 98166    7.743007   12.625942   -1.000000   45.758161   -1.000000    6.179840
# 98167    7.743007   12.625942   -1.000000   45.758161   -1.000000    6.179840
# 98168    7.743007   12.625942   -1.000000   45.758161   -1.000000    6.179840
#
#         avg_risk   adj_risk
# 0      10.050825  10.050825
# 1      10.050825  10.050825
# 2      10.050825  10.050825
# 3      10.050825  10.050825
# 4      10.050825  10.050825
# ...          ...        ...
# 98164  12.051158  12.051158
# 98165  12.051158  12.051158
# 98166  12.051158  12.051158
# 98167  12.051158  12.051158
# 98168  12.051158  12.051158
#
# [98169 rows x 18 columns]

# %%
tank_risks_merged.to_file('/hpc/group/codeplus22-vis/infousa_copy/tanks_risk_score_final.shp')
# Out:
# /tmp/ipykernel_320985/3102571742.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   tank_risks_merged.to_file('/hpc/group/codeplus22-vis/infousa_copy/tanks_risk_score_final.shp')
